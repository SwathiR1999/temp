# %%
# %cd /content/drive/MyDrive/Zero_Shot_DeepFake_Image_Classification
# Out:
# /content/drive/MyDrive/Zero_Shot_DeepFake_Image_Classification

# %%
# !pip install torch_dct joblib --quiet

# %%
dataset_path = "DeepfakeEmpiricalStudy/dataset/CELEB"
save_model_path = "DeepfakeEmpiricalStudy_Models"

# %%
# !python DeepfakeEmpiricalStudy_Code/DCT_classifier/dct_classifier.py DeepfakeEmpiricalStudy/dataset/CELEB --input_size 256 --epochs 10 --lr 0.01
# Out:
# final array shape torch.Size([8000, 1, 256, 256])
# final array shape torch.Size([8000, 1, 256, 256])
# final array shape torch.Size([1000, 1, 256, 256])
# final array shape torch.Size([1000, 1, 256, 256])
# feature calculation...
# reshaped...
# rescaled...
# training model...
# /content/drive/MyDrive/Zero_Shot_DeepFake_Image_Classification/DeepfakeEmpiricalStudy_Code/DCT_classifier/dct_classifier.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(self.labels[idx])
# Epoch 1:
# Train Loss: 0.8858, Train Accuracy: 0.4977
# Valid Loss: 0.6932, Valid Accuracy: 0.5000
# Epoch 2:
# Train Loss: 0.6969, Train Accuracy: 0.4946
# Valid Loss: 0.6937, Valid Accuracy: 0.4985
# Traceback (most recent call last):
# ...
