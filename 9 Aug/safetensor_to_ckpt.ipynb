# %%
# !!pip install timm==0.4.5
# Out:
# ['Collecting timm==0.4.5',
#  '  Downloading timm-0.4.5-py3-none-any.whl.metadata (24 kB)',
#  'Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.4.5) (2.3.1+cu121)',
#  'Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.4.5) (0.18.1+cu121)',
#  'Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (3.15.4)',
#  'Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (4.12.2)',
#  'Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (1.13.1)',
#  'Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (3.3)',
#  'Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.5) (3.1.4)',
# ...

# %%
# %cd 'drive/MyDrive/Aerial_Scene_Recognition/safetensor_to_ckpt/'
# Out:
# /content/drive/MyDrive/Aerial_Scene_Recognition/safetensor_to_ckpt

# %%
import timm

# %%
import torch
from safetensors.torch import load_file

# %%
model = load_file('model.safetensors')

# %%
torch.save(model, 'model.pth')

# %%
timm.list_models()
# Out:
# ['adv_inception_v3',
#  'cspdarknet53',
#  'cspdarknet53_iabn',
#  'cspresnet50',
#  'cspresnet50d',
#  'cspresnet50w',
#  'cspresnext50',
#  'cspresnext50_iabn',
#  'darknet53',
#  'densenet121',
#  'densenet121d',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'densenet264',
#  'densenet264d_iabn',
#  'densenetblur121d',
#  'dla34',
#  'dla46_c',
#  'dla46x_c',
#  'dla60',
#  'dla60_res2net',
#  'dla60_res2next',
#  'dla60x',
#  'dla60x_c',
#  'dla102',
#  'dla102x',
#  'dla102x2',
#  'dla169',
#  'dm_nfnet_f0',
#  'dm_nfnet_f1',
#  'dm_nfnet_f2',
#  'dm_nfnet_f3',
#  'dm_nfnet_f4',
#  'dm_nfnet_f5',
#  'dm_nfnet_f6',
#  'dpn68',
#  'dpn68b',
#  'dpn92',
#  'dpn98',
#  'dpn107',
#  'dpn131',
#  'eca_vovnet39b',
#  'ecaresnet26t',
#  'ecaresnet50d',
#  'ecaresnet50d_pruned',
#  'ecaresnet50t',
#  'ecaresnet101d',
#  'ecaresnet101d_pruned',
#  'ecaresnet200d',
#  'ecaresnet269d',
#  'ecaresnetlight',
#  'ecaresnext26t_32x4d',
#  'ecaresnext50t_32x4d',
#  'efficientnet_b0',
# ...

# %%
'vit_base_patch16_224' in timm.list_models()
# Out:
# True

# %%
model = timm.create_model('vit_base_patch16_224', checkpoint_path = 'model.pth')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-1522356c9d53> in <cell line: 1>()
# ----> 1 model = timm.create_model('vit_base_patch16_224', checkpoint_path = 'model.pth')
#
# /usr/local/lib/python3.10/dist-packages/timm/models/factory.py in create_model(model_name, pretrained, checkpoint_path, scriptable, exportable, no_jit, **kwargs)
#      56
#      57     if checkpoint_path:
# ---> 58         load_checkpoint(model, checkpoint_path)
#      59
#      60     return model
#
# /usr/local/lib/python3.10/dist-packages/timm/models/helpers.py in load_checkpoint(model, checkpoint_path, use_ema, strict)
#      50 def load_checkpoint(model, checkpoint_path, use_ema=False, strict=True):
#      51     state_dict = load_state_dict(checkpoint_path, use_ema)
# ---> 52     model.load_state_dict(state_dict, strict=strict)
#      53
#      54
#
# ...
